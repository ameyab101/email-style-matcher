# %% [markdown]
# # Email Style Matcher – Demo
#
# Upload a few of **your own emails** → the system learns your **writing style** → generates a new email **in the same voice**.
#
# ---
#
# ### 1. Load sample data

# %%
style_num = 1  #change this to test others

# %%
import pandas as pd

# This CSV is in data/sample_emails.csv (included in repo)
df = pd.read_csv(f'data/sample_emails_{style_num}.csv')
print(f"--- STYLE {style_num} EMAILS ---")
df
# Out:
# --- STYLE 1 EMAILS ---
#                   email_id                                            subject  \
# 1 Quick update    Hey team  \n\nJust wanted to say the meeting went great!...
# 2 Re: Project     Hi Sarah  \n\nThanks for the feedback. I’ll tweak the de...
# 3 Weekend plans?   Hey all  \n\nAnyone up for coffee Saturday? ☕ I’m free ...
#
#                     body
# 1 Quick update    \nAlex
# 2 Re: Project     \nAlex
# 3 Weekend plans?  \nAlex

# %% [markdown]
# ### 2. Extract your style

# %%
from analyze_style import extract_style

style = extract_style(df)
print("Detected style →", style)
# Out:
# Detected style → {'formality': 'formal', 'uses_emoji': False, 'avg_words': 1, 'greeting': 'Hi', 'closing': 'Best'}

# %% [markdown]
# ### 3. Generate a new email in **your** voice

# %%
from generate_email import generate_in_style

# Change topic / audience to anything you like
new_email = generate_in_style(
    style,
    topic="a new project idea",
    audience="the team"
)
print("\n--- Generated email ---\n")
print(new_email)
# Out:
# --- Generated email ---
#
# Hi Team,
#
# I have a new project idea that I believe could enhance our current efforts. I would love to discuss it further and gather your thoughts. Please let me know when you are available for a brief meeting.
#
# Best,

# %%
# Try langchain

from generate_email_langchain import generate_in_style as gen_lc

print("LangChain:", gen_lc(style, topic="test"))
# Out:
# LangChain: Hi Team,
#
# I hope this message finds you well. I wanted to remind everyone about the upcoming test scheduled for next week. Please ensure you review the materials and reach out if you have any questions.
#
# Best,
# [Your Name]
